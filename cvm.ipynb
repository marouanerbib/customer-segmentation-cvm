# %% [markdown]
# # 1. Configuration de l'environnement
# ## Importation des bibliothèques nécessaires

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Configuration des graphiques
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')
# %matplotlib inline

print("Bibliothèques importées avec succès.")
# Out:
# Bibliothèques importées avec succès.

# %% [markdown]
# ## Chargement et aperçu du dataset
# Lecture du fichier `base_seg_gsm.csv` et affichage des premières lignes.

# %%
# Chargement des données

df = pd.read_csv("base_seg_gsm.csv")
print(f"Dataset chargé avec succès ! Dimensions : {df.shape}")
display(df.head())
# Out:
# Dataset chargé avec succès ! Dimensions : (8000, 13)
#       ID  MMPR  FREQR  POIDS_VAS  POIDS_IN  POIDS_IN_OFFN  POIDS_OPK  \
# 0    6.0  20.0    5.0   0.012244  0.032905       0.800251   0.912323
# 1   18.0  20.0    1.0   0.000000  0.930400       0.254946   0.642126
# 2   62.0  10.0    1.0   0.152091  0.623734       0.693735   0.283647
# 3  109.0   0.0    0.0   0.000000  0.791667       0.848297   0.181373
# 4  123.0  42.5    4.0   0.035871  0.205944       0.986124   0.117165
#
#    POIDS_ONG  POIDS_INT  POIDS_ONN  SMART_PHONE  MULTI_EQUIPE  USERS_INTERNET
# 0   0.301724   0.571299   0.960274          0.0           0.0             0.0
# 1   0.000000   0.604382   0.694052          0.0           0.0             0.0
# 2   0.000000   0.518100   0.360347          0.0           0.0             0.0
# 3   0.000000   0.879562   0.328431          0.0           0.0             0.0
# 4   0.000000   0.807484   0.613069          1.0           0.0             0.0

# %% [markdown]
# # 2. Analyse Exploratoire des Données (EDA)
# ## Informations générales et statistiques descriptives
# Vérification des types de données, des valeurs manquantes et résumé statistique des variables numériques.

# %%
# Informations sur les colonnes et types
print("--- Infos du DataFrame ---")
df.info()

print("\n--- Statistiques descriptives ---")
# Affichage transposé pour une meilleure lisibilité
display(df.describe().T)

print("\n--- Vérification des valeurs manquantes ---")
print(df.isnull().sum())
# Out:
# --- Infos du DataFrame ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              8000 non-null   float64
#  1   MMPR            8000 non-null   float64
#  2   FREQR           8000 non-null   float64
#  3   POIDS_VAS       8000 non-null   float64
#  4   POIDS_IN        8000 non-null   float64
#  5   POIDS_IN_OFFN   8000 non-null   float64
#  6   POIDS_OPK       8000 non-null   float64
#  7   POIDS_ONG       8000 non-null   float64
#  8   POIDS_INT       8000 non-null   float64
#  9   POIDS_ONN       8000 non-null   float64
#  10  SMART_PHONE     8000 non-null   float64
#  11  MULTI_EQUIPE    8000 non-null   float64
#  12  USERS_INTERNET  8000 non-null   float64
# dtypes: float64(13)
# memory usage: 812.6 KB
#
# --- Statistiques descriptives ---
#                  count         mean          std  min          25%  \
# ID              8000.0  4000.500000  2309.545410  1.0  2000.750000
# MMPR            8000.0    14.854495    12.584311  0.0    10.000000
# FREQR           8000.0     5.218375     7.586048  0.0     1.000000
# POIDS_VAS       8000.0     0.104456     0.207971  0.0     0.000000
# POIDS_IN        8000.0     0.405651     0.377379  0.0     0.024068
# POIDS_IN_OFFN   8000.0     0.201513     0.301497  0.0     0.000391
# POIDS_OPK       8000.0     0.492158     0.310413  0.0     0.219915
# POIDS_ONG       8000.0     0.281528     0.391424  0.0     0.000000
# POIDS_INT       8000.0     0.047899     0.167504  0.0     0.000000
# POIDS_ONN       8000.0     0.823016     0.243414  0.0     0.745797
# SMART_PHONE     8000.0     0.104500     0.305927  0.0     0.000000
# MULTI_EQUIPE    8000.0     0.113625     0.317375  0.0     0.000000
# USERS_INTERNET  8000.0     0.113875     0.317679  0.0     0.000000
#
#                          50%          75%          max
# ID              4.000500e+03  6000.250000  8000.000000
# MMPR            1.375000e+01    20.000000   250.000000
# FREQR           3.000000e+00     6.000000   116.000000
# POIDS_VAS       1.049028e-11     0.100200     1.000000
# POIDS_IN        3.053337e-01     0.781187     1.000000
# POIDS_IN_OFFN   3.233159e-02     0.294433     0.999928
# POIDS_OPK       4.920279e-01     0.759924     1.000000
# POIDS_ONG       0.000000e+00     0.638264     1.000000
# POIDS_INT       0.000000e+00     0.000000     1.000000
# POIDS_ONN       9.402037e-01     0.988559     1.000000
# SMART_PHONE     0.000000e+00     0.000000     1.000000
# MULTI_EQUIPE    0.000000e+00     0.000000     1.000000
# USERS_INTERNET  0.000000e+00     0.000000     1.000000
# --- Vérification des valeurs manquantes ---
# ID                0
# MMPR              0
# FREQR             0
# POIDS_VAS         0
# POIDS_IN          0
# POIDS_IN_OFFN     0
# POIDS_OPK         0
# POIDS_ONG         0
# POIDS_INT         0
# POIDS_ONN         0
# SMART_PHONE       0
# MULTI_EQUIPE      0
# USERS_INTERNET    0
# dtype: int64

# %% [markdown]
# ## Visualisation des distributions
# Analyse de la répartition des variables clés (`MMPR`, `FREQR`, `POIDS_...`) pour identifier les tendances et les valeurs aberrantes.

# %%
# Sélection des colonnes numériques (exclusion de l'ID si présent)
cols_numeriques = df.select_dtypes(include=['float64', 'int64']).columns
if 'ID' in cols_numeriques:
    cols_numeriques = cols_numeriques.drop('ID')

# Histogrammes
plt.figure(figsize=(20, 15))
for i, col in enumerate(cols_numeriques):
    plt.subplot(4, 4, i + 1)
    sns.histplot(df[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution de {col}')
    plt.tight_layout()
plt.show()

# Boxplots (pour mieux voir les outliers)
plt.figure(figsize=(20, 15))
for i, col in enumerate(cols_numeriques):
    plt.subplot(4, 4, i + 1)
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f'Boxplot de {col}')
    plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analyse des corrélations
# Utilisation d'une heatmap pour visualiser les relations linéaires entre les variables.
# Points d'attention :
# - Forte corrélation attendue entre usage Data et Smartphone.
# - Liens entre valeur (MMPR) et fréquence (FREQR).

# %%
# Calcul de la matrice de corrélation
cols_corr = df.drop('ID', axis=1) # On enlève l'ID qui n'a pas de sens statistique
corr_matrix = cols_corr.corr()

# Affichage de la Heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5, vmin=-1, vmax=1)
plt.title('Matrice de Corrélation des Variables', fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# # 3. Préparation des données (Preprocessing)
# ## Standardisation
# Le K-Means étant sensible aux échelles, nous allons centrer et réduire nos variables numériques (moyenne = 0, écart-type = 1).

# %%
# Sélection des features pour le clustering
features = df.columns.tolist()
if 'ID' in features:
    features.remove('ID')

# Standardisation (Centrage-Réduction)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[features])

# Création d'un DataFrame pour vérifier le résultat
df_scaled = pd.DataFrame(X_scaled, columns=features)
print("Données standardisées. Aperçu des 5 premières lignes :")
display(df_scaled.head())

print("\n\nMoyennes :")
print(df_scaled.mean().round(2))
print("\nÉcart-types:")
print(df_scaled.std().round(2))
# Out:
# Données standardisées. Aperçu des 5 premières lignes :
#        MMPR     FREQR  POIDS_VAS  POIDS_IN  POIDS_IN_OFFN  POIDS_OPK  \
# 0  0.408908 -0.028788  -0.443414 -0.987784       1.986007   1.353652
# 1  0.408908 -0.556105  -0.502294  1.390594       0.177235   0.483154
# 2 -0.385782 -0.556105   0.229064  0.577924       1.632696  -0.671764
# 3 -1.180472 -0.687934  -0.502294  1.022949       2.145375  -1.001263
# 4  2.196960 -0.160617  -0.329804 -0.529227       2.602545  -1.208121
#
#    POIDS_ONG  POIDS_INT  POIDS_ONN  SMART_PHONE  MULTI_EQUIPE  USERS_INTERNET
# 0   0.051601   3.124888   0.563923    -0.341606     -0.358037       -0.358481
# 1  -0.719286   3.322410  -0.529849    -0.341606     -0.358037       -0.358481
# 2  -0.719286   2.807269  -1.900867    -0.341606     -0.358037       -0.358481
# 3  -0.719286   4.965334  -2.031994    -0.341606     -0.358037       -0.358481
# 4  -0.719286   4.535001  -0.862564     2.927350     -0.358037       -0.358481
# Moyennes :
# MMPR             -0.0
# FREQR            -0.0
# POIDS_VAS         0.0
# POIDS_IN          0.0
# POIDS_IN_OFFN    -0.0
# POIDS_OPK         0.0
# POIDS_ONG        -0.0
# POIDS_INT         0.0
# POIDS_ONN         0.0
# SMART_PHONE      -0.0
# MULTI_EQUIPE     -0.0
# USERS_INTERNET    0.0
# dtype: float64
#
# Écart-types:
# MMPR              1.0
# FREQR             1.0
# POIDS_VAS         1.0
# POIDS_IN          1.0
# POIDS_IN_OFFN     1.0
# POIDS_OPK         1.0
# POIDS_ONG         1.0
# POIDS_INT         1.0
# POIDS_ONN         1.0
# SMART_PHONE       1.0
# MULTI_EQUIPE      1.0
# USERS_INTERNET    1.0
# dtype: float64

# %% [markdown]
# # 4. Modélisation : Segmentation par Clustering K-Means
# Nous appliquons l'algorithme K-Means pour diviser nos 8000 clients en **8 segments distincts**, comme requis par le projet.

# %%
# Configuration du modèle K-Means avec K=8
k = 8
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)

# Entraînement du modèle sur les données standardisées
kmeans.fit(X_scaled)

# Ajout des labels de cluster au DataFrame original (non standardisé)
# Cela nous permettra d'interpréter les résultats avec les vraies valeurs (ex: vrai montant MMPR)
df['Cluster'] = kmeans.labels_

print(f"Segmentation terminée avec {k} clusters.")
print("\nRépartition des clients par cluster :")
print(df['Cluster'].value_counts().sort_index())

# Calcul du coefficient de silhouette pour évaluer la qualité (entre -1 et 1)
# Plus c'est proche de 1, mieux les clusters sont séparés.
sil_score = silhouette_score(X_scaled, kmeans.labels_)
print(f"\nScore de Silhouette global : {sil_score:.3f}")
# Out:
# Segmentation terminée avec 8 clusters.
#
# Répartition des clients par cluster :
# Cluster
# 0     736
# 1    1333
# 2    1432
# 3     488
# 4    2144
# 5     777
# 6     354
# 7     736
# Name: count, dtype: int64
#
# Score de Silhouette global : 0.221

# %% [markdown]
# # 5. Interprétation des Résultats : Profiling
# Calcul des moyennes de chaque variable pour chaque cluster afin de comprendre le comportement type des clients de chaque segment.

# %%
# Sélection des colonnes à analyser (tout sauf ID et Cluster)
cols_analyse = [col for col in df.columns if col not in ['ID', 'Cluster']]

# Calcul des moyennes par cluster
cluster_means = df.groupby('Cluster')[cols_analyse].mean().round(2)

# Ajout de la taille de chaque cluster (nombre de clients)
cluster_means['Taille'] = df['Cluster'].value_counts()

# Tri par valeur (MMPR) décroissante pour faciliter la lecture
cluster_means = cluster_means.sort_values('MMPR', ascending=False)

# Affichage avec un dégradé de couleur
display(cluster_means.style.background_gradient(cmap='YlGnBu', axis=0))
# Out:
# <style type="text/css">
# #T_2cee8_row0_col0, #T_2cee8_row0_col1, #T_2cee8_row0_col9, #T_2cee8_row1_col7, #T_2cee8_row2_col11, #T_2cee8_row3_col6, #T_2cee8_row3_col8, #T_2cee8_row4_col12, #T_2cee8_row5_col2, #T_2cee8_row6_col4, #T_2cee8_row6_col10, #T_2cee8_row7_col3, #T_2cee8_row7_col5 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_2cee8_row0_col2, #T_2cee8_row0_col7, #T_2cee8_row2_col4, #T_2cee8_row6_col9 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_2cee8_row0_col3 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_2cee8_row0_col4, #T_2cee8_row0_col12, #T_2cee8_row2_col12 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# #T_2cee8_row0_col5 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_2cee8_row0_col6 {
#   background-color: #87d0ba;
#   color: #000000;
# }
# #T_2cee8_row0_col8 {
#   background-color: #243d98;
#   color: #f1f1f1;
# }
# #T_2cee8_row0_col10, #T_2cee8_row3_col2, #T_2cee8_row6_col7 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_2cee8_row0_col11 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_2cee8_row1_col0 {
#   background-color: #2073b2;
#   color: #f1f1f1;
# }
# #T_2cee8_row1_col1 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_2cee8_row1_col2, #T_2cee8_row2_col2 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# #T_2cee8_row1_col3 {
#   background-color: #52bcc2;
#   color: #000000;
# }
# #T_2cee8_row1_col4, #T_2cee8_row5_col3 {
#   background-color: #3fb4c4;
#   color: #f1f1f1;
# }
# #T_2cee8_row1_col5 {
#   background-color: #e9f7b1;
#   color: #000000;
# }
# #T_2cee8_row1_col6 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_2cee8_row1_col8 {
#   background-color: #6fc7bd;
#   color: #000000;
# }
# #T_2cee8_row1_col9 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_2cee8_row1_col10, #T_2cee8_row2_col10, #T_2cee8_row3_col10, #T_2cee8_row5_col7, #T_2cee8_row6_col2 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_2cee8_row1_col11, #T_2cee8_row6_col11, #T_2cee8_row7_col9 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_2cee8_row1_col12, #T_2cee8_row2_col7, #T_2cee8_row3_col4, #T_2cee8_row3_col7, #T_2cee8_row3_col9, #T_2cee8_row3_col11, #T_2cee8_row4_col2, #T_2cee8_row4_col3, #T_2cee8_row4_col7, #T_2cee8_row4_col9, #T_2cee8_row4_col10, #T_2cee8_row4_col11, #T_2cee8_row6_col5, #T_2cee8_row6_col6, #T_2cee8_row6_col8, #T_2cee8_row7_col0, #T_2cee8_row7_col1, #T_2cee8_row7_col2, #T_2cee8_row7_col4, #T_2cee8_row7_col6, #T_2cee8_row7_col7, #T_2cee8_row7_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_2cee8_row2_col0, #T_2cee8_row4_col8 {
#   background-color: #1f7bb6;
#   color: #f1f1f1;
# }
# #T_2cee8_row2_col1 {
#   background-color: #59bfc0;
#   color: #000000;
# }
# #T_2cee8_row2_col3 {
#   background-color: #b9e4b5;
#   color: #000000;
# }
# #T_2cee8_row2_col5 {
#   background-color: #24419a;
#   color: #f1f1f1;
# }
# #T_2cee8_row2_col6, #T_2cee8_row3_col5 {
#   background-color: #21318d;
#   color: #f1f1f1;
# }
# #T_2cee8_row2_col8 {
#   background-color: #0c2060;
#   color: #f1f1f1;
# }
# #T_2cee8_row2_col9, #T_2cee8_row5_col11 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_2cee8_row3_col0 {
#   background-color: #269bc1;
#   color: #f1f1f1;
# }
# #T_2cee8_row3_col1, #T_2cee8_row4_col0 {
#   background-color: #55bec1;
#   color: #000000;
# }
# #T_2cee8_row3_col3 {
#   background-color: #b2e1b6;
#   color: #000000;
# }
# #T_2cee8_row3_col12 {
#   background-color: #2397c1;
#   color: #f1f1f1;
# }
# #T_2cee8_row4_col1 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_2cee8_row4_col4, #T_2cee8_row4_col5 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# #T_2cee8_row4_col6 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_2cee8_row5_col0 {
#   background-color: #69c5be;
#   color: #000000;
# }
# #T_2cee8_row5_col1 {
#   background-color: #ceecb3;
#   color: #000000;
# }
# #T_2cee8_row5_col4 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_2cee8_row5_col5 {
#   background-color: #42b6c4;
#   color: #f1f1f1;
# }
# #T_2cee8_row5_col6 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_2cee8_row5_col8 {
#   background-color: #234fa1;
#   color: #f1f1f1;
# }
# #T_2cee8_row5_col9 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_2cee8_row5_col10 {
#   background-color: #d5efb3;
#   color: #000000;
# }
# #T_2cee8_row5_col12 {
#   background-color: #f4fbc1;
#   color: #000000;
# }
# #T_2cee8_row6_col0 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_2cee8_row6_col1 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_2cee8_row6_col3 {
#   background-color: #1e83ba;
#   color: #f1f1f1;
# }
# #T_2cee8_row6_col12 {
#   background-color: #cbebb4;
#   color: #000000;
# }
# #T_2cee8_row7_col8 {
#   background-color: #1b2c80;
#   color: #f1f1f1;
# }
# #T_2cee8_row7_col10 {
#   background-color: #a5dcb7;
#   color: #000000;
# }
# #T_2cee8_row7_col12 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2cee8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cee8_level0_col0" class="col_heading level0 col0" >MMPR</th>
#       <th id="T_2cee8_level0_col1" class="col_heading level0 col1" >FREQR</th>
#       <th id="T_2cee8_level0_col2" class="col_heading level0 col2" >POIDS_VAS</th>
#       <th id="T_2cee8_level0_col3" class="col_heading level0 col3" >POIDS_IN</th>
#       <th id="T_2cee8_level0_col4" class="col_heading level0 col4" >POIDS_IN_OFFN</th>
#       <th id="T_2cee8_level0_col5" class="col_heading level0 col5" >POIDS_OPK</th>
#       <th id="T_2cee8_level0_col6" class="col_heading level0 col6" >POIDS_ONG</th>
#       <th id="T_2cee8_level0_col7" class="col_heading level0 col7" >POIDS_INT</th>
#       <th id="T_2cee8_level0_col8" class="col_heading level0 col8" >POIDS_ONN</th>
#       <th id="T_2cee8_level0_col9" class="col_heading level0 col9" >SMART_PHONE</th>
#       <th id="T_2cee8_level0_col10" class="col_heading level0 col10" >MULTI_EQUIPE</th>
#       <th id="T_2cee8_level0_col11" class="col_heading level0 col11" >USERS_INTERNET</th>
#       <th id="T_2cee8_level0_col12" class="col_heading level0 col12" >Taille</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cee8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2cee8_row0_col0" class="data row0 col0" >25.370000</td>
#       <td id="T_2cee8_row0_col1" class="data row0 col1" >13.800000</td>
#       <td id="T_2cee8_row0_col2" class="data row0 col2" >0.080000</td>
#       <td id="T_2cee8_row0_col3" class="data row0 col3" >0.270000</td>
#       <td id="T_2cee8_row0_col4" class="data row0 col4" >0.220000</td>
#       <td id="T_2cee8_row0_col5" class="data row0 col5" >0.460000</td>
#       <td id="T_2cee8_row0_col6" class="data row0 col6" >0.320000</td>
#       <td id="T_2cee8_row0_col7" class="data row0 col7" >0.040000</td>
#       <td id="T_2cee8_row0_col8" class="data row0 col8" >0.880000</td>
#       <td id="T_2cee8_row0_col9" class="data row0 col9" >0.990000</td>
#       <td id="T_2cee8_row0_col10" class="data row0 col10" >0.020000</td>
#       <td id="T_2cee8_row0_col11" class="data row0 col11" >0.210000</td>
#       <td id="T_2cee8_row0_col12" class="data row0 col12" >736</td>
#     </tr>
#     <tr>
#       <th id="T_2cee8_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_2cee8_row1_col0" class="data row1 col0" >19.610000</td>
#       <td id="T_2cee8_row1_col1" class="data row1 col1" >4.860000</td>
#       <td id="T_2cee8_row1_col2" class="data row1 col2" >0.090000</td>
#       <td id="T_2cee8_row1_col3" class="data row1 col3" >0.470000</td>
#       <td id="T_2cee8_row1_col4" class="data row1 col4" >0.430000</td>
#       <td id="T_2cee8_row1_col5" c

# %% [markdown]
# # 6. Visualisation des Profils (Snake Plot)
# Graphique montrant les écarts-types de chaque variable par rapport à la moyenne globale (ligne 0).
# Permet d'identifier visuellement les pics caractéristiques de chaque cluster.

# %%
# Préparation des données pour le Snake Plot
# On reprend le DataFrame standardisé 'df_scaled' et on lui remet les clusters
df_scaled['Cluster'] = kmeans.labels_

# Transformation en format long pour Seaborn ('melt')
df_melt = pd.melt(df_scaled.reset_index(),
                  id_vars=['Cluster'],
                  value_vars=features,
                  var_name='Variable',
                  value_name='Valeur_Standardisee')

# Création du graphique
plt.figure(figsize=(18, 10))
sns.lineplot(x='Variable', y='Valeur_Standardisee', hue='Cluster', data=df_melt, palette='tab10', marker='o')

# Ajout d'une ligne de référence à 0 (moyenne globale)
plt.axhline(0, color='black', linestyle='--', linewidth=1)

plt.title('Snake Plot des 8 Segments Marketing', fontsize=18, fontweight='bold')
plt.xlabel('Variables', fontsize=12)
plt.ylabel('Écart à la moyenne (Z-Score)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Cluster', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7. Export des Résultats
# Sauvegarde du fichier final avec la colonne `Cluster` et les labels marketing associés.

# %%
# Dictionnaire pour nommer les clusters (basé sur le Plan d'Action CVM)
noms_segments = {
    0: 'Elite Connectée',        # Fort ARPU, Smartphone (99%), Usage mixte.
    1: 'Receveurs Économes',     # Faible budget, reçoit principalement, 0% Data.
    2: 'Fugueurs Off-Net',       # Fort usage vers la concurrence (83% ONG).
    3: 'Accros aux Services (VAS)', # Fort usage Services à Valeur Ajoutée (jeux, contenus).
    4: 'La Majorité Silencieuse', # Profil moyen standard, usage voix on-line.
    5: 'Opportunistes Multi-SIM', # Multi-équipés (68%), reçoivent de la concurrence.
    6: 'Globe-Trotters',         # Fort usage international (74%).
    7: '100% Digital'            # Usage Data exclusif (100% Users), voix faible.
}

# Application des noms
df['Segment_Name'] = df['Cluster'].map(noms_segments)

# Aperçu final
display(df[['ID', 'MMPR', 'Cluster', 'Segment_Name']].head())

# Export vers CSV
df.to_csv('resultats_segmentation_cvm.csv', index=False)
print("Fichier 'resultats_segmentation_cvm.csv' exporté avec succès.")
# Out:
#       ID  MMPR  Cluster    Segment_Name
# 0    6.0  20.0        6  Globe-Trotters
# 1   18.0  20.0        6  Globe-Trotters
# 2   62.0  10.0        6  Globe-Trotters
# 3  109.0   0.0        6  Globe-Trotters
# 4  123.0  42.5        6  Globe-Trotters
# Fichier 'resultats_segmentation_cvm.csv' exporté avec succès.

# %%
clusters_actions = {
    0: {
        "name": "Elite Connectee",
        "action": "Programme VIP avec service client dedie + ligne prioritaire 24/7"
    },
    1: {
        "name": "Receveurs Economes",
        "action": "Systeme de fidelisation par appel + 'Premier Data' : 1GB gratuit pendant 3 mois"
    },
    2: {
        "name": "Fugueurs Off-Net",
        "action": "Forfait d'appel illimite + extension heures gratuite de 20h a 22h"
    },
    3: {
        "name": "Accros aux Services (VAS)",
        "action": "Abonnement aux services a -50% sur une duree determinee"
    },
    4: {
        "name": "La Majorite Silencieuse",
        "action": "Bonus recharge 50% : pour toute recharge 100DH -> recevoir 150DH"
    },
    5: {
        "name": "Opportunistes Multi-SIM",
        "action": "Forfait 'Data Champion' : 20GB a 50DH/mois"
    },
    6: {
        "name": "Globe-Trotters",
        "action": "Package international illimite vers 10 destinations"
    },
    7: {
        "name": "100% Digital",
        "action": "Acces prioritaire 5G + 20GB bonus data mensuels"
    }
}

# Display
for cluster_id, info in clusters_actions.items():
    print(f"Cluster {cluster_id} : {info['name']}")
    print(f"Action : {info['action']}")
    print("-" * 60)
# Out:
# Cluster 0 : Elite Connectee
# Action : Programme VIP avec service client dedie + ligne prioritaire 24/7
# ------------------------------------------------------------
# Cluster 1 : Receveurs Economes
# Action : Systeme de fidelisation par appel + 'Premier Data' : 1GB gratuit pendant 3 mois
# ------------------------------------------------------------
# Cluster 2 : Fugueurs Off-Net
# Action : Forfait d'appel illimite + extension heures gratuite de 20h a 22h
# ------------------------------------------------------------
# Cluster 3 : Accros aux Services (VAS)
# Action : Abonnement aux services a -50% sur une duree determinee
# ------------------------------------------------------------
# Cluster 4 : La Majorite Silencieuse
# Action : Bonus recharge 50% : pour toute recharge 100DH -> recevoir 150DH
# ------------------------------------------------------------
# Cluster 5 : Opportunistes Multi-SIM
# Action : Forfait 'Data Champion' : 20GB a 50DH/mois
# ------------------------------------------------------------
# Cluster 6 : Globe-Trotters
# Action : Package international illimite vers 10 destinations
# ------------------------------------------------------------
# Cluster 7 : 100% Digital
# Action : Acces prioritaire 5G + 20GB bonus data mensuels
# ------------------------------------------------------------

# %% [markdown]
# # 8 .ANALYSER LES PROFILS RÉELS
#
# regardons les vraies caractéristiques de chaque cluster.
